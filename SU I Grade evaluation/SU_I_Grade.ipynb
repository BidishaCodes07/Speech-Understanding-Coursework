# %%
import torch
import librosa
import pandas as pd
import os
import numpy as np
import tarfile

# %%
# !pip install transformers
# !pip install datasets evaluate
# !pip install jiwer
# !pip install speechbrain
# !pip install bitsandbytes
# !pip install accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 kB 36.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.4 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoProcessor, AutoModelforSpeechSeq2Seq, BitsAndBytesconfig
from speechbrain.pretrained import EncoderDecoderASR
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-3d99a77da567> in <cell line: 0>()
# ----> 1 from transformers import AutoProcessor, AutoModelforSpeechSeq2Seq, BitsAndBytesconfig
#       2 from speechbrain.pretrained import EncoderDecoderASR
#
# ImportError: cannot import name 'AutoModelforSpeechSeq2Seq' from 'transformers' (/usr/local/lib/python3.11/dist-packages/transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
file_name="test-clean.tar.gz"
data_dir="LibriSpeech"

# %%
model_whisper="openai/whisper-base"
processor_whisper=AutoProcessor.from_pretrained(model_whisper)
model_whisper_fp32= AutoModelforSpeechSeq2Seq.from_pretrained(
    model_whisper, torch_dtype=torch.float32
    ).to(device)
predictions_fp32=[]
references=[sample{"transcription"}]
for sample in tqdm(subset_data):
  input_features= processor.whisper(
      sample["audio"]["array"], sampling_rate=sample["audio"]["sampling_rate"]

  ).input_features.to(device)
  predicted=model_whisper_fp32.generate(input_features)
  predictions.append(predicted)

model_whisper_fp16= AutoModelforSpeechSeq2Seq.from_pretrained(
    model_whisper, torch_dtype=torch.float16
    ).to(device)
predictions_fp16=[]
references=[sample{"transcription"}]
for sample in tqdm(subset_data):
  input_features= processor.whisper(
      sample["audio"]["array"], sampling_rate=sample["audio"]["sampling_rate"]

  ).input_features.to(device)
  predicted_fp16=model_whisper_fp16.generate(input_features)
  predictions.append(predicted_fp16)


model_whisper_int8= AutoModelforSpeechSeq2Seq.from_pretrained(
    model_whisper, torch_dtype=torch.unint8
  ).to(device)
predictions_int8=[]
references=[sample{"transcription"}]
for sample in tqdm(subset_data):
  input_features= processor.whisper(
      sample["audio"]["array"], sampling_rate=sample["audio"]["sampling_rate"]

  ).input_features.to(device)
  predicted=model_whisper_int8.generate(input_features)
  predictions.append(predicted)
# Out:
#   File "<ipython-input-7-44d54272e06f>", line 7
#     references=[sample{"transcription"}]
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
